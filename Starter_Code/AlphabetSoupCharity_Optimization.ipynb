# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Determine the number of unique values in each column.
# Target variable looks like IS_SUCCESSFUL, with other values as the features
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
application_type_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = application_type_counts[application_type_counts<=500].index.tolist()
application_types_to_replace

# # Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts[classification_counts > 1]
classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = classification_counts[classification_counts < 1000].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays
# Target variable (y) is 'IS SUCCESSFUl'
# Features are the rest of the columns (excluding) 'IS SUCCESSFUL'
y = application_df['IS_SUCCESSFUL']
X = application_df.drop(columns = ['IS_SUCCESSFUL']).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model - Optimization Attempt 1. Adding more neurons

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=12, activation="relu", input_dim=43))

# First hidden layer
# Units = neurons
# Input_dimensions = # of features you have (we have 43 after dropping the Is_Successful column)
nn_model.add(tf.keras.layers.Dense(units=12, activation="relu"))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=12, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 12)                528
#
#  dense_1 (Dense)             (None, 12)                156
#
#  dense_2 (Dense)             (None, 12)                156
#
#  dense_3 (Dense)             (None, 1)                 13
#
# ...
# Total params: 853
# Trainable params: 853
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
# Binary crossentropy is trying to see if you get type 1 or type 2 errors
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
# Using 100 epochs per sample output
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5967 - accuracy: 0.7009
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5628 - accuracy: 0.7235
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5572 - accuracy: 0.7280
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5546 - accuracy: 0.7285
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5527 - accuracy: 0.7304
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7312
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7318
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5502 - accuracy: 0.7323
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7332
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
# First pass at optimization has loss of .553 and accuracy of .724
# Loss = squared average difference from what you predicted vs what the real value is
# Accuracy = ratio between correct predictions and number of predictions in the data set
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5540 - accuracy: 0.7243 - 588ms/epoch - 2ms/step
# Loss: 0.5539663434028625, Accuracy: 0.7243148684501648

# %% [markdown]
# ## Compile, Train and Evaluate the Model - Optimization Attempt 2. Leaving neurons from 1 and changing activation functions for hidden layers

# %%
nn_model_2 = tf.keras.models.Sequential()
nn_model_2.add(tf.keras.layers.Dense(units=12, activation="relu", input_dim=43))

# First hidden layer
# Units = neurons
# Input_dimensions = # of features you have (we have 43 after dropping the Is_Successful column)
nn_model_2.add(tf.keras.layers.Dense(units=12, activation="tanh"))

# Second hidden layer
nn_model_2.add(tf.keras.layers.Dense(units=12, activation="tanh"))

# Output layer
nn_model_2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 12)                528
#
#  dense_5 (Dense)             (None, 12)                156
#
#  dense_6 (Dense)             (None, 12)                156
#
#  dense_7 (Dense)             (None, 1)                 13
#
# ...
# Total params: 853
# Trainable params: 853
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
# Binary crossentropy is trying to see if you get type 1 or type 2 errors
nn_model_2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
# Using 100 epochs per sample output
fit_model_2 = nn_model_2.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5781 - accuracy: 0.7152
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5574 - accuracy: 0.7302
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5542 - accuracy: 0.7300
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5524 - accuracy: 0.7313
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7313
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5511 - accuracy: 0.7317
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5500 - accuracy: 0.7324
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7316
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5491 - accuracy: 0.7329
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
# Second pass at optimization has slightly higher loss of .554 and accuracy of .726
# Loss = squared average difference from what you predicted vs what the real value is
# Accuracy = ratio between correct predictions and number of predictions in the data set
model_loss_2, model_accuracy_2 = nn_model_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss_2}, Accuracy: {model_accuracy_2}")
# Out:
# 268/268 - 1s - loss: 0.5535 - accuracy: 0.7262 - 512ms/epoch - 2ms/step
# Loss: 0.5535395741462708, Accuracy: 0.7261807322502136

# %% [markdown]
# ## Compile, Train and Evaluate the Model - Optimization Attempt 3. Leaving neurons from 1, changing back activation function to relu, and adding another hidden layer

# %%
nn_model_3 = tf.keras.models.Sequential()
nn_model_3.add(tf.keras.layers.Dense(units=12, activation="relu", input_dim=43))

# First hidden layer
# Units = neurons
# Input_dimensions = # of features you have (we have 43 after dropping the Is_Successful column)
nn_model_3.add(tf.keras.layers.Dense(units=12, activation="relu"))

# Second hidden layer
nn_model_3.add(tf.keras.layers.Dense(units=12, activation="relu"))

# Third hidden layer
nn_model_3.add(tf.keras.layers.Dense(units=12, activation="relu"))

# Output layer
nn_model_3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 12)                528
#
#  dense_9 (Dense)             (None, 12)                156
#
#  dense_10 (Dense)            (None, 12)                156
#
#  dense_11 (Dense)            (None, 12)                156
#
#  dense_12 (Dense)            (None, 1)                 13
#
# ...
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
# Binary crossentropy is trying to see if you get type 1 or type 2 errors
nn_model_3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
# Using 100 epochs per sample output
fit_model_3 = nn_model_3.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5941 - accuracy: 0.7025
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5592 - accuracy: 0.7308
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5559 - accuracy: 0.7314
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5538 - accuracy: 0.7314
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5520 - accuracy: 0.7329
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7327
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7335
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7345
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7341
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
# Second pass at optimization has slightly higher loss of .552 and accuracy of .726 (slightly lower than before)
# Loss = squared average difference from what you predicted vs what the real value is
# Accuracy = ratio between correct predictions and number of predictions in the data set
model_loss_3, model_accuracy_3 = nn_model_3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss_3}, Accuracy: {model_accuracy_3}")

# %%
nn_model.save('AlphabetSoupCharity_Optimization.h5')
